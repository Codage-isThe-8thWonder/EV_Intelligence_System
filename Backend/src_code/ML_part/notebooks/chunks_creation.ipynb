# %%
import pandas as pd
df = pd.read_csv("../datasets/simulation_dataset.csv")
print(df.shape)
df.head()
# Out:
# (26309, 30)
#              Timestamp       SoC       SoH  Battery_Voltage  Battery_Current  \
# 0  2024-04-01 23:00:00  0.881918  0.594962       362.809211      -107.132101
# 1  2024-04-01 23:15:00  0.842283  0.913706       366.830017       -17.909172
# 2  2024-04-01 23:30:00  0.812015  0.939819       358.105357       -12.700803
# 3  2024-04-01 23:45:00  0.861919  0.933208       357.150815       -34.398991
# 4  2024-04-02 00:00:00  0.987063  0.988339       363.333079       -32.396753
#
#    Battery_Temperature  Charge_Cycles  Motor_Temperature  Motor_Vibration  \
# 0            26.531187     582.151378          59.692655         0.232854
# 1            25.080270     116.705122          58.130642         0.258170
# 2            27.054168     169.602803          48.317422         1.803575
# 3            31.029168     125.607724          46.034486         0.222447
# 4            58.690601     134.269162          48.278553         1.760410
#
# ...

# %%
df.drop(["RUL","Failure_Probability","TTF","Component_Health_Score","Maintenance_Type"],axis=1,inplace=True)

# %%
df.head()
# Out:
#              Timestamp       SoC       SoH  Battery_Voltage  Battery_Current  \
# 0  2024-04-01 23:00:00  0.881918  0.594962       362.809211      -107.132101
# 1  2024-04-01 23:15:00  0.842283  0.913706       366.830017       -17.909172
# 2  2024-04-01 23:30:00  0.812015  0.939819       358.105357       -12.700803
# 3  2024-04-01 23:45:00  0.861919  0.933208       357.150815       -34.398991
# 4  2024-04-02 00:00:00  0.987063  0.988339       363.333079       -32.396753
#
#    Battery_Temperature  Charge_Cycles  Motor_Temperature  Motor_Vibration  \
# 0            26.531187     582.151378          59.692655         0.232854
# 1            25.080270     116.705122          58.130642         0.258170
# 2            27.054168     169.602803          48.317422         1.803575
# 3            31.029168     125.607724          46.034486         0.222447
# 4            58.690601     134.269162          48.278553         1.760410
#
# ...

# %% [markdown]
# ### Renaming Important Columns owing to the Database convention

# %%
df = df.rename(columns={
    "Timestamp": "timestamp",

    "SoC": "soc",
    "SoH": "soh",

    "Battery_Voltage": "battery_voltage",
    "Battery_Current": "battery_current",
    "Battery_Temperature": "battery_temperature",

    "Charge_Cycles": "charge_cycles",

    "Motor_Temperature": "motor_temperature",
    "Motor_Vibration": "motor_vibration",
    "Motor_Torque": "motor_torque",
    "Motor_RPM": "motor_rpm",

    "Power_Consumption": "power_consumption",

    "Brake_Pad_Wear": "brake_pad_wear",
    "Brake_Pressure": "brake_pressure",
    "Reg_Brake_Efficiency": "reg_brake_efficiency",

    "Tire_Pressure": "tire_pressure",
    "Tire_Temperature": "tire_temperature",

    "Suspension_Load": "suspension_load",

    "Ambient_Temperature": "ambient_temperature",
    "Ambient_Humidity": "ambient_humidity",

    "Load_Weight": "load_weight",

    "Driving_Speed": "driving_speed",
    "Distance_Traveled": "distance_traveled",

    "Idle_Time": "idle_time",

    "Route_Roughness": "route_roughness"
})

# %%
df.head()
# Out:
#              timestamp       soc       soh  battery_voltage  battery_current  \
# 0  2024-04-01 23:00:00  0.881918  0.594962       362.809211      -107.132101
# 1  2024-04-01 23:15:00  0.842283  0.913706       366.830017       -17.909172
# 2  2024-04-01 23:30:00  0.812015  0.939819       358.105357       -12.700803
# 3  2024-04-01 23:45:00  0.861919  0.933208       357.150815       -34.398991
# 4  2024-04-02 00:00:00  0.987063  0.988339       363.333079       -32.396753
#
#    battery_temperature  charge_cycles  motor_temperature  motor_vibration  \
# 0            26.531187     582.151378          59.692655         0.232854
# 1            25.080270     116.705122          58.130642         0.258170
# 2            27.054168     169.602803          48.317422         1.803575
# 3            31.029168     125.607724          46.034486         0.222447
# 4            58.690601     134.269162          48.278553         1.760410
#
# ...

# %%
num_vehicles = 6
chunk_size = len(df) // num_vehicles

chunk_size
# Out:
# 4384

# %%
vehicle_names = [
    "EV_101",
    "EV_102",
    "EV_201",
    "EV_301",
    "EV_302",
    "EV_303"
]

for i, vehicle in enumerate(vehicle_names):

    start = i * chunk_size

    if i == len(vehicle_names) - 1:
        end = len(df)
    else:
        end = (i + 1) * chunk_size

    chunk = df.iloc[start:end]

    chunk.to_csv(
        f"../datasets/EV_simulated_chunks/{vehicle}.csv",
        index=False
    )

    print(vehicle, chunk.shape)
# Out:
# EV_101 (4384, 25)
# EV_102 (4384, 25)
# EV_201 (4384, 25)
# EV_301 (4384, 25)
# EV_302 (4384, 25)
# EV_303 (4389, 25)
